# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("multilinear_regression_large_data.csv")

# %%
df.head(3)
# Out:
#    Age  Years of Experience  Salary ($1000s)
# 0   50                    1               73
# 1   36                   14               97
# 2   29                    3               58

# %%
df.isnull().sum()
# Out:
# Age                    0
# Years of Experience    0
# Salary ($1000s)        0
# dtype: int64

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <Axes: >

# %%
x = df.iloc[:,:-1]
y =df["Salary ($1000s)"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 , random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lr.fit(x_test , y_test)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 92.77758287534976

# %%
# y = m1x1+m2x2+c

# %%
lr.coef_
# Out:
# array([1.39269722, 3.43158745])

# %%
lr.intercept_
# Out:
# -2.3741234604824086

# %%
# y_prd = 1.39269722*Age+3.43158745*Experience

# %%
x.columns
# Out:
# Index(['Age', 'Years of Experience'], dtype='object')

# %%
lr.predict(x_test)
# Out:
# array([140.81708257,  69.94582093,  64.92091382, 102.02218276,
#        128.72837813,  75.31598739,  85.71106095, 150.06440704,
#        111.77106332,  70.69232515, 107.59297165, 159.06678338,
#        112.11632267, 118.23299334, 156.82727072,  70.49170271,
#        141.50760127,  68.89838305, 102.12249397,  77.15425517])
