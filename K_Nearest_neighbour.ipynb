# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression , LogisticRegression
from sklearn.tree import DecisionTreeRegressor , plot_tree , DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("new_Social_Network_Ads.csv")

# %%
df.head(3)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
x = df.iloc[:,:-1]
y = df["Purchased"]

# %%
x_train, x_test ,  y_train , y_test = train_test_split(x, y, test_size=0.2 , random_state=42)

# %%
sns.scatterplot(x="Age" , y="EstimatedSalary" , data=df , hue="Purchased")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x) , columns=x.columns)

# %%
x
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
x_train , x_test , y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.neighbors import kneighbors_graph , KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# TIP -- as yu change the value of the neighbour the accuracy of the model changes 

knn.fit(x_train , y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
knn.score(x_test , y_test)*100
# Out:
# 93.75

# %%
knn.score(x_test , y_test)*100
# Out:
# 93.75

# %%
# if there is some recursive work them add the loops

# %%
for i in range(1,30):
    knn1 = KNeighborsClassifier()
    knn1.fit(x_train , y_train)
    print(i , knn1.score(x_test , y_test)*100 , knn1.score(x_train , y_train)*100)
# Out:
# 1 92.5 90.9375
# 2 92.5 90.9375
# 3 92.5 90.9375
# 4 92.5 90.9375
# 5 92.5 90.9375
# 6 92.5 90.9375
# 7 92.5 90.9375
# 8 92.5 90.9375
# 9 92.5 90.9375
# 10 92.5 90.9375
# 11 92.5 90.9375
# 12 92.5 90.9375
# 13 92.5 90.9375
# 14 92.5 90.9375
# 15 92.5 90.9375
# 16 92.5 90.9375
# 17 92.5 90.9375
# 18 92.5 90.9375
# 19 92.5 90.9375
# 20 92.5 90.9375
# 21 92.5 90.9375
# 22 92.5 90.9375
# 23 92.5 90.9375
# 24 92.5 90.9375
# 25 92.5 90.9375
# 26 92.5 90.9375
# 27 92.5 90.9375
# 28 92.5 90.9375
# 29 92.5 90.9375

# %%
knn.predict([[-1.781797 , -1.490046 ]])
# Out:
# c:\Users\HP\healthcare\noman\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy() , clf=knn)
plt.show()
# Out:
# c:\Users\HP\healthcare\noman\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
