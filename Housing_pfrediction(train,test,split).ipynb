# %%
import pandas as pd

# %%
df = pd.read_csv("boston.csv")

# %%
df.head(3)
# Out:
#          TOWN  TRACT     LON      LAT  MEDV     CRIM    ZN  INDUS  CHAS  \
# 0      Nahant   2011 -70.955  42.2550  24.0  0.00632  18.0   2.31     0
# 1  Swampscott   2021 -70.950  42.2875  21.6  0.02731   0.0   7.07     0
# 2  Swampscott   2022 -70.936  42.2830  34.7  0.02729   0.0   7.07     0
#
#      NOX     RM   AGE     DIS  RAD  TAX  PTRATIO
# 0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.469  7.185  61.1  4.9671    2  242     17.8

# %%
input_data = df.iloc[: , : -1]

# %%
input_data
# Out:
#            TOWN  TRACT      LON      LAT  MEDV     CRIM    ZN  INDUS  CHAS  \
# 0        Nahant   2011 -70.9550  42.2550  24.0  0.00632  18.0   2.31     0
# 1    Swampscott   2021 -70.9500  42.2875  21.6  0.02731   0.0   7.07     0
# 2    Swampscott   2022 -70.9360  42.2830  34.7  0.02729   0.0   7.07     0
# 3    Marblehead   2031 -70.9280  42.2930  33.4  0.03237   0.0   2.18     0
# 4    Marblehead   2032 -70.9220  42.2980  36.2  0.06905   0.0   2.18     0
# ..          ...    ...      ...      ...   ...      ...   ...    ...   ...
# 501    Winthrop   1801 -70.9860  42.2312  22.4  0.06263   0.0  11.93     0
# 502    Winthrop   1802 -70.9910  42.2275  20.6  0.04527   0.0  11.93     0
# 503    Winthrop   1803 -70.9948  42.2260  23.9  0.06076   0.0  11.93     0
# 504    Winthrop   1804 -70.9875  42.2240  22.0  0.10959   0.0  11.93     0
# 505    Winthrop   1805 -70.9825  42.2210  19.0  0.04741   0.0  11.93     0
#
#        NOX     RM   AGE     DIS  RAD  TAX
# ...

# %%
output_data = df["PTRATIO"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_test , y_train = train_test_split(input_data, output_data , test_size=0.25)

# input data = means here the data in x direction 
#output data = means here the data in y direction

# %%
x_test
# Out:
#                     TOWN  TRACT      LON      LAT  MEDV      CRIM    ZN  \
# 185              Belmont   3577 -71.1175  42.2350  29.6   0.06047   0.0
# 395  Boston South Boston    603 -71.0220  42.1996  13.1   8.71675   0.0
# 409      Boston Downtown    706 -71.0455  42.2060  27.5  14.43830   0.0
# 153            Cambridge   3532 -71.0645  42.2150  19.4   2.14918   0.0
# 403  Boston South Boston    612 -71.0332  42.1980   8.3  24.80170   0.0
# ..                   ...    ...      ...      ...   ...       ...   ...
# 292             Westwood   4123 -71.1070  42.1307  27.9   0.03615  80.0
# 350             Scituate   5052 -70.8330  42.1150  22.9   0.06211  40.0
# 294              Norwood   4132 -71.1180  42.1217  21.7   0.08199   0.0
# 307               Milton   4164 -71.0280  42.1565  28.2   0.04932  33.0
# 370   Boston Beacon Hill    201 -71.0422  42.2144  50.0   6.53876   0.0
#
#      INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX
# ...

# %%
x_train
# Out:
#                     TOWN  TRACT      LON      LAT  MEDV      CRIM    ZN  \
# 384   Boston East Boston    503 -71.0245  42.2235   8.8  20.08490   0.0
# 330             Randolph   4203 -71.0250  42.0980  19.8   0.04544   0.0
# 265            Brookline   4009 -71.0700  42.2000  22.8   0.76162  20.0
# 174            Arlington   3563 -71.0833  42.2475  22.6   0.08447   0.0
# 475  Boston Forest Hills   1203 -71.0511  42.1879  13.3   6.39312   0.0
# ..                   ...    ...      ...      ...   ...       ...   ...
# 118               Malden   3418 -71.0285  42.2580  20.4   0.13058   0.0
# 203               Weston   3671 -71.1990  42.2320  48.5   0.03510  95.0
# 67            Wilmington   3311 -71.0900  42.3362  22.0   0.05789  12.5
# 164            Cambridge   3543 -71.0918  42.2265  22.7   2.24236   0.0
# 416       Boston Roxbury    803 -71.0477  42.1965   7.5  10.83420   0.0
#
#      INDUS  CHAS     NOX     RM   AGE     DIS  RAD  TAX
# ...

# %%
y_test
# Out:
# 384    20.2
# 330    16.9
# 265    13.0
# 174    16.6
# 475    20.2
#        ...
# 118    17.8
# 203    14.7
# 67     18.9
# 164    14.7
# 416    20.2
# Name: PTRATIO, Length: 379, dtype: float64

# %%
x_train.shape
# Out:
# (379, 15)

# %%
x_test.shape
# Out:
# (127, 15)

# %%
y_train.shape
# Out:
# (127,)

# %%
y_train
# Out:
# 185    17.8
# 395    20.2
# 409    20.2
# 153    14.7
# 403    20.2
#        ...
# 292    19.2
# 350    19.7
# 294    16.0
# 307    18.4
# 370    20.2
# Name: PTRATIO, Length: 127, dtype: float64

# %%
y_train.shape
# Out:
# (127,)
