# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from  sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression , LogisticRegression

# %%
df = pd.read_csv("polynomial_classification_dataset.csv")

# %%
df.head(3)
# Out:
#          X1        X2  Class
# 0 -2.509198 -6.297341      0
# 1  9.014286  0.838019      0
# 2  4.639879  7.458917      1

# %%
plt.figure(figsize=(4,5))
sns.scatterplot(x="X1", y="X2" , data=df , hue="Class")
plt.show()

# %%
x = df.iloc[:,:-1]
y = df["Class"]

# %%
x_test, x_train, y_test , y_train = train_test_split(x,y,test_size=0.2 , random_state=42)

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)*100
# Out:
# 90.75

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy() , y.to_numpy() , clf=lr)
# Out:
# c:\Users\HP\healthcare\noman\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
# go to the new notebokk  ploynomial featuire is appplied there

# %%
# the the new notrbook is in the name , new_feature
